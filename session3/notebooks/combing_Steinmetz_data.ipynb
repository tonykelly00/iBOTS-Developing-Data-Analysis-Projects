# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# First we need to make sure our python environment knows about the folder "src" (we only need to do this once)
import sys
sys.path.append('../src')

# %%
from import_data import combine_data, plot_data

# %%
input="../data/raw/subject-Lederberg/session-20171209/behavioral/licks/"
licks_data=combine_data(input, '.npy')
plot_data(licks_data, 'licks')
# Out:
# data: 100%|██████████| 390/390 [00:00<00:00, 808.75it/s]

# %%
input="../data/raw/subject-Lederberg/session-20171209/behavioral/face/"
licks_data=combine_data(input)
plot_data(licks_data, 'face')
# Out:
# data: 100%|██████████| 390/390 [00:00<00:00, 1115.44it/s]

# %%
input="../data/raw/subject-Lederberg/session-20171209/behavioral/wheel_speed/"
wheel_speed_data=combine_data(input)

fig, ax = plt.subplots(figsize=(4, 3), dpi=150)
ax.plot(wheel_speed_data.T, c="k", alpha=.1)
ax.set(xlabel="time", ylabel="wheel speed")
# Out:
# data: 100%|██████████| 390/390 [00:00<00:00, 945.11it/s]
# [Text(0.5, 0, 'time'), Text(0, 0.5, 'wheel speed')]

# %%
input="../data/raw/subject-Lederberg/session-20171209/behavioral/puplil/"
pupil_area_data=combine_data(input, '.mat')
# Out:
# data: 0it [00:00, ?it/s]
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Tony Kelly\AppData\Local\Temp\ipykernel_3716\3001644774.py", line 2, in <module>
#     pupil_area_data=combine_data(input, '.mat')
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tony Kelly\Desktop\iBOT_project\iBOTS-Developing-Data-Analysis-Projects\session3\notebooks\../src\import_data.py", line 17, in combine_data
#     np_data = np.stack(data)
#               ^^^^^^^^^^^^^^
#   File "<__array_function__ internals>", line 200, in stack
#   File "c:\anaconda3\Lib\site-packages\numpy\core\shape_base.py", line 460, in stack
#     raise ValueError('need at least one array to stack')
# ValueError: need at least one array to stack
#
# ...

# %% [markdown]
# Mo's version

# %%
from pathlib import Path

Path(input).name
# Out:
# 'puplil'
